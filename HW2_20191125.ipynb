# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
x = np.linspace(-5, 5, 201)
y = np.linspace(-5, 5, 201)
lim = np.arange(-2,2.1,0.1)
x_1,y_1 = np.meshgrid(x,y)

z_1 = np.cos(X) * np.sin(Y)
plt.subplot(121)
plt.contourf(x_1, y_1, z_1, lim, cmap="jet")

z_2 = 5*np.cos(X)*np.sin(Y)
plt.subplot(122)
plt.contourf(x_1, y_1, z_2, lim, cmap="jet")

plt.show()
